# %% [markdown]
# Optimize the Model

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://raw.githubusercontent.com/slstapleton/Neural_Network_Charity_Analysis/main/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(labels=["EIN", "NAME"], axis=1)

# %%
# Look at APPLICATION_TYPE value counts for binning
application_counts = application_df.APPLICATION_TYPE.value_counts()

# Determine which values to replace if counts are less than ...?
replace_application = list(application_counts[application_counts < 500].index)

# Replace in dataframe
for app in replace_application:
    application_df.APPLICATION_TYPE = application_df.APPLICATION_TYPE.replace(app,"Other")

# %%
# Look at CLASSIFICATION value counts for binning
class_counts = application_df.CLASSIFICATION.value_counts()

# Determine which values to replace if counts are less than ..?
replace_class = list(class_counts[class_counts < 1800].index)

# Replace in dataframe
for cls in replace_class:
    application_df.CLASSIFICATION = application_df.CLASSIFICATION.replace(cls,"Other")

# %%
# Generate our categorical variable lists
application_cat = list(application_df.dtypes[application_df.dtypes == "object"].index)

# %%
# Create a OneHotEncoder instance
enc = OneHotEncoder(sparse=False)

# Fit and transform the OneHotEncoder using the categorical variable list
encode_df = pd.DataFrame(enc.fit_transform(application_df[application_cat]))

# Add the encoded variable names to the dataframe
encode_df.columns = enc.get_feature_names(application_cat)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Merge one-hot encoded features and drop the originals
application_df = application_df.merge(encode_df, left_index=True, right_index=True)
application_df = application_df.drop(labels=application_cat, axis=1)

# %%
# Split our preprocessed data into our features and target arrays
y = application_df["IS_SUCCESSFUL"].values.reshape(-1, 1)
X = application_df.drop("IS_SUCCESSFUL", axis=1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# Increase Epoch

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 30

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                3520
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 5,981
# Trainable params: 5,981
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Add model weight checkpoints during training
import os
from tensorflow.keras.callbacks import ModelCheckpoint
os.makedirs("checkpoints/", exist_ok=True)
checkpoint_path="checkpoints/weights.{epoch}.hdf5"

# Create a callback that saves the model's weights every epoch
cp_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=5,
    save_weights_only=True,
    save_freq='epoch')

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=200,callbacks=[cp_callback])
# Out:
# Epoch 1/200
# 792/804 [============================>.] - ETA: 0s - loss: 0.5708 - accuracy: 0.7207
# Epoch 1: saving model to checkpoints/weights.1.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5707 - accuracy: 0.7209
# Epoch 2/200
# 789/804 [============================>.] - ETA: 0s - loss: 0.5571 - accuracy: 0.7264
# Epoch 2: saving model to checkpoints/weights.2.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5565 - accuracy: 0.7271
# Epoch 3/200
# 784/804 [============================>.] - ETA: 0s - loss: 0.5535 - accuracy: 0.7292
# Epoch 3: saving model to checkpoints/weights.3.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5539 - accuracy: 0.7288
# Epoch 4/200
# 779/804 [============================>.] - ETA: 0s - loss: 0.5521 - accuracy: 0.7286
# Epoch 4: saving model to checkpoints/weights.4.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5522 - accuracy: 0.7290
# Epoch 5/200
# 800/804 [============================>.] - ETA: 0s - loss: 0.5501 - accuracy: 0.7312
# Epoch 5: saving model to checkpoints/weights.5.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5500 - accuracy: 0.7311
# Epoch 6/200
# 792/804 [============================>.] - ETA: 0s - loss: 0.5500 - accuracy: 0.7318
# Epoch 6: saving model to checkpoints/weights.6.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5499 - accuracy: 0.7316
# Epoch 7/200
# 779/804 [============================>.] - ETA: 0s - loss: 0.5480 - accuracy: 0.7318
# Epoch 7: saving model to checkpoints/weights.7.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5493 - accuracy: 0.7301
# Epoch 8/200
# 785/804 [============================>.] - ETA: 0s - loss: 0.5483 - accuracy: 0.7333
# Epoch 8: saving model to checkpoints/weights.8.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5488 - accuracy: 0.7328
# Epoch 9/200
# 786/804 [============================>.] - ETA: 0s - loss: 0.5474 - accuracy: 0.7336
# Epoch 9: saving model to checkpoints/weights.9.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5477 - accuracy: 0.7331
# Epoch 10/200
# 799/804 [============================>.] - ETA: 0s - loss: 0.5474 - accuracy: 0.7329
# Epoch 10: saving model to checkpoints/weights.10.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5474 - accuracy: 0.7329
# Epoch 11/200
# 779/804 [============================>.] - ETA: 0s - loss: 0.5474 - accuracy: 0.7332
# Epoch 11: saving model to checkpoints/weights.11.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5474 - accuracy: 0.7333
# Epoch 12/200
# 795/804 [============================>.] - ETA: 0s - loss: 0.5463 - accuracy: 0.7344
# Epoch 12: saving model to checkpoints/weights.12.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5465 - accuracy: 0.7345
# Epoch 13/200
# 802/804 [============================>.] - ETA: 0s - loss: 0.5464 - accuracy: 0.7333
# Epoch 13: saving model to checkpoints/weights.13.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5463 - accuracy: 0.7334
# Epoch 14/200
# 802/804 [============================>.] - ETA: 0s - loss: 0.5462 - accuracy: 0.7343
# Epoch 14: saving model to checkpoints/weights.14.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5462 - accuracy: 0.7344
# Epoch 15/200
# 804/804 [==============================] - ETA: 0s - loss: 0.5455 - accuracy: 0.7341
# Epoch 15: saving model to checkpoints/weights.15.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5455 - accuracy: 0.7341
# Epoch 16/200
# 778/804 [============================>.] - ETA: 0s - loss: 0.5451 - accuracy: 0.7337
# Epoch 16: saving model to checkpoints/weights.16.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5455 - accuracy: 0.7335
# Epoch 17/200
# 793/804 [============================>.] - ETA: 0s - loss: 0.5449 - accuracy: 0.7355
# Epoch 17: saving model to checkpoints/weights.17.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5454 - accuracy: 0.7346
# Epoch 18/200
# 801/804 [============================>.] - ETA: 0s - loss: 0.5449 - accuracy: 0.7355
# Epoch 18: saving model to checkpoints/weights.18.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5448 - accuracy: 0.7355
# Epoch 19/200
# 800/804 [============================>.] - ETA: 0s - loss: 0.5452 - accuracy: 0.7352
# Epoch 19: saving model to checkpoints/weights.19.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5453 - accuracy: 0.7352
# Epoch 20/200
# 793/804 [============================>.] - ETA: 0s - loss: 0.5440 - accuracy: 0.7349
# Epoch 20: saving model to checkpoints/weights.20.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5440 - accuracy: 0.7348
# Epoch 21/200
# 792/804 [============================>.] - ETA: 0s - loss: 0.5434 - accuracy: 0.7343
# Epoch 21: saving model to checkpoints/weights.21.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5439 - accuracy: 0.7341
# Epoch 22/200
# 788/804 [============================>.] - ETA: 0s - loss: 0.5443 - accuracy: 0.7348
# Epoch 22: saving model to checkpoints/weights.22.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5441 - accuracy: 0.7348
# Epoch 23/200
# 788/804 [============================>.] - ETA: 0s - loss: 0.5433 - accuracy: 0.7358
# Epoch 23: saving model to checkpoints/weights.23.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5435 - accuracy: 0.7355
# Epoch 24/200
# 798/804 [============================>.] - ETA: 0s - loss: 0.5434 - accuracy: 0.7358
# Epoch 24: saving model to checkpoints/weights.24.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5437 - accuracy: 0.7355
# Epoch 25/200
# 796/804 [============================>.] - ETA: 0s - loss: 0.5437 - accuracy: 0.7360
# Epoch 25: saving model to checkpoints/weights.25.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5434 - accuracy: 0.7361
# Epoch 26/200
# 803/804 [============================>.] - ETA: 0s - loss: 0.5440 - accuracy: 0.7349
# Epoch 26: saving model to checkpoints/weights.26.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5441 - accuracy: 0.7348
# Epoch 27/200
# 802/804 [============================>.] - ETA: 0s - loss: 0.5426 - accuracy: 0.7359
# Epoch 27: saving model to checkpoints/weights.27.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5426 - accuracy: 0.7359
# Epoch 28/200
# 798/804 [============================>.] - ETA: 0s - loss: 0.5431 - accuracy: 0.7368
# Epoch 28: saving model to checkpoints/weights.28.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5433 - accuracy: 0.7367
# Epoch 29/200
# 798/804 [============================>.] - ETA: 0s - loss: 0.5430 - accuracy: 0.7354
# Epoch 29: saving model to checkpoints/weights.29.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5428 - accuracy: 0.7356
# Epoch 30/200
# 783/804 [============================>.] - ETA: 0s - loss: 0.5416 - accuracy: 0.7364
# Epoch 30: saving model to checkpoints/weights.30.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5427 - accuracy: 0.7357
# Epoch 31/200
# 783/804 [============================>.] - ETA: 0s - loss: 0.5427 - accuracy: 0.7370
# Epoch 31: saving model to checkpoints/weights.31.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5424 - accuracy: 0.7368
# Epoch 32/200
# 789/804 [============================>.] - ETA: 0s - loss: 0.5424 - accuracy: 0.7373
# Epoch 32: saving model to checkpoints/weights.32.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5424 - accuracy: 0.7371
# Epoch 33/200
# 786/804 [============================>.] - ETA: 0s - loss: 0.5421 - accuracy: 0.7373
# Epoch 33: saving model to checkpoints/weights.33.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5419 - accuracy: 0.7369
# Epoch 34/200
# 795/804 [============================>.] - ETA: 0s - loss: 0.5424 - accuracy: 0.7352
# Epoch 34: saving model to checkpoints/weights.34.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5423 - accuracy: 0.7359
# Epoch 35/200
# 804/804 [==============================] - ETA: 0s - loss: 0.5418 - accuracy: 0.7364
# Epoch 35: saving model to checkpoints/weights.35.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5418 - accuracy: 0.7364
# Epoch 36/200
# 778/804 [============================>.] - ETA: 0s - loss: 0.5412 - accuracy: 0.7368
# Epoch 36: saving model to checkpoints/weights.36.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5416 - accuracy: 0.7367
# Epoch 37/200
# 794/804 [============================>.] - ETA: 0s - loss: 0.5408 - accuracy: 0.7374
# Epoch 37: saving model to checkpoints/weights.37.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5413 - accuracy: 0.7372
# Epoch 38/200
# 800/804 [============================>.] - ETA: 0s - loss: 0.5416 - accuracy: 0.7367
# Epoch 38: saving model to checkpoints/weights.38.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5418 - accuracy: 0.7365
# Epoch 39/200
# 790/804 [============================>.] - ETA: 0s - loss: 0.5411 - accuracy: 0.7367
# Epoch 39: saving model to checkpoints/weights.39.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5411 - accuracy: 0.7369
# Epoch 40/200
# 804/804 [==============================] - ETA: 0s - loss: 0.5411 - accuracy: 0.7370
# Epoch 40: saving model to checkpoints/weights.40.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5411 - accuracy: 0.7370
# Epoch 41/200
# 782/804 [============================>.] - ETA: 0s - loss: 0.5412 - accuracy: 0.7359
# Epoch 41: saving model to checkpoints/weights.41.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5413 - accuracy: 0.7360
# Epoch 42/200
# 786/804 [============================>.] - ETA: 0s - loss: 0.5413 - accuracy: 0.7382
# Epoch 42: saving model to checkpoints/weights.42.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5411 - accuracy: 0.7383
# Epoch 43/200
# 797/804 [============================>.] - ETA: 0s - loss: 0.5407 - accuracy: 0.7367
# Epoch 43: saving model to checkpoints/weights.43.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5409 - accuracy: 0.7363
# Epoch 44/200
# 777/804 [===========================>..] - ETA: 0s - loss: 0.5412 - accuracy: 0.7366
# Epoch 44: saving model to checkpoints/weights.44.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5408 - accuracy: 0.7371
# Epoch 45/200
# 804/804 [==============================] - ETA: 0s - loss: 0.5409 - accuracy: 0.7375
# Epoch 45: saving model to checkpoints/weights.45.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5409 - accuracy: 0.7375
# Epoch 46/200
# 777/804 [===========================>..] - ETA: 0s - loss: 0.5408 - accuracy: 0.7372
# Epoch 46: saving model to checkpoints/weights.46.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5406 - accuracy: 0.7372
# Epoch 47/200
# 777/804 [===========================>..] - ETA: 0s - loss: 0.5394 - accuracy: 0.7399
# Epoch 47: saving model to checkpoints/weights.47.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5409 - accuracy: 0.7383
# Epoch 48/200
# 777/804 [===========================>..] - ETA: 0s - loss: 0.5411 - accuracy: 0.7373
# Epoch 48: saving model to checkpoints/weights.48.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5403 - accuracy: 0.7380
# Epoch 49/200
# 781/804 [============================>.] - ETA: 0s - loss: 0.5406 - accuracy: 0.7370
# Epoch 49: saving model to checkpoints/weights.49.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5402 - accuracy: 0.7371
# Epoch 50/200
# 788/804 [============================>.] - ETA: 0s - loss: 0.5402 - accuracy: 0.7373
# Epoch 50: saving model to checkpoints/weights.50.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5399 - accuracy: 0.7375
# Epoch 51/200
# 797/804 [============================>.] - ETA: 0s - loss: 0.5407 - accuracy: 0.7375
# Epoch 51: saving model to checkpoints/weights.51.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5405 - accuracy: 0.7376
# Epoch 52/200
# 802/804 [============================>.] - ETA: 0s - loss: 0.5399 - accuracy: 0.7373
# Epoch 52: saving model to checkpoints/weights.52.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5399 - accuracy: 0.7373
# Epoch 53/200
# 782/804 [============================>.] - ETA: 0s - loss: 0.5401 - accuracy: 0.7378
# Epoch 53: saving model to checkpoints/weights.53.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5399 - accuracy: 0.7376
# Epoch 54/200
# 796/804 [============================>.] - ETA: 0s - loss: 0.5400 - accuracy: 0.7383
# Epoch 54: saving model to checkpoints/weights.54.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5401 - accuracy: 0.7383
# Epoch 55/200
# 798/804 [============================>.] - ETA: 0s - loss: 0.5401 - accuracy: 0.7373
# Epoch 55: saving model to checkpoints/weights.55.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5397 - accuracy: 0.7377
# Epoch 56/200
# 803/804 [============================>.] - ETA: 0s - loss: 0.5398 - accuracy: 0.7372
# Epoch 56: saving model to checkpoints/weights.56.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5400 - accuracy: 0.7372
# Epoch 57/200
# 787/804 [============================>.] - ETA: 0s - loss: 0.5406 - accuracy: 0.7365
# Epoch 57: saving model to checkpoints/weights.57.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5397 - accuracy: 0.7370
# Epoch 58/200
# 792/804 [============================>.] - ETA: 0s - loss: 0.5397 - accuracy: 0.7380
# Epoch 58: saving model to checkpoints/weights.58.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5398 - accuracy: 0.7378
# Epoch 59/200
# 792/804 [============================>.] - ETA: 0s - loss: 0.5398 - accuracy: 0.7382
# Epoch 59: saving model to checkpoints/weights.59.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5397 - accuracy: 0.7382
# Epoch 60/200
# 794/804 [============================>.] - ETA: 0s - loss: 0.5392 - accuracy: 0.7389
# Epoch 60: saving model to checkpoints/weights.60.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5393 - accuracy: 0.7389
# Epoch 61/200
# 794/804 [============================>.] - ETA: 0s - loss: 0.5387 - accuracy: 0.7385
# Epoch 61: saving model to checkpoints/weights.61.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5388 - accuracy: 0.7383
# Epoch 62/200
# 779/804 [============================>.] - ETA: 0s - loss: 0.5386 - accuracy: 0.7389
# Epoch 62: saving model to checkpoints/weights.62.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5394 - accuracy: 0.7380
# Epoch 63/200
# 777/804 [===========================>..] - ETA: 0s - loss: 0.5387 - accuracy: 0.7378
# Epoch 63: saving model to checkpoints/weights.63.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5393 - accuracy: 0.7373
# Epoch 64/200
# 795/804 [============================>.] - ETA: 0s - loss: 0.5400 - accuracy: 0.7379
# Epoch 64: saving model to checkpoints/weights.64.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5394 - accuracy: 0.7380
# Epoch 65/200
# 794/804 [============================>.] - ETA: 0s - loss: 0.5384 - accuracy: 0.7385
# Epoch 65: saving model to checkpoints/weights.65.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5390 - accuracy: 0.7379
# Epoch 66/200
# 775/804 [===========================>..] - ETA: 0s - loss: 0.5393 - accuracy: 0.7388
# Epoch 66: saving model to checkpoints/weights.66.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5391 - accuracy: 0.7386
# Epoch 67/200
# 802/804 [============================>.] - ETA: 0s - loss: 0.5389 - accuracy: 0.7379
# Epoch 67: saving model to checkpoints/weights.67.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5389 - accuracy: 0.7379
# Epoch 68/200
# 789/804 [============================>.] - ETA: 0s - loss: 0.5386 - accuracy: 0.7393
# Epoch 68: saving model to checkpoints/weights.68.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5389 - accuracy: 0.7392
# Epoch 69/200
# 785/804 [============================>.] - ETA: 0s - loss: 0.5382 - accuracy: 0.7378
# Epoch 69: saving model to checkpoints/weights.69.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5388 - accuracy: 0.7376
# Epoch 70/200
# 794/804 [============================>.] - ETA: 0s - loss: 0.5383 - accuracy: 0.7385
# Epoch 70: saving model to checkpoints/weights.70.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5385 - accuracy: 0.7382
# Epoch 71/200
# 780/804 [============================>.] - ETA: 0s - loss: 0.5390 - accuracy: 0.7377
# Epoch 71: saving model to checkpoints/weights.71.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5388 - accuracy: 0.7379
# Epoch 72/200
# 780/804 [============================>.] - ETA: 0s - loss: 0.5384 - accuracy: 0.7390
# Epoch 72: saving model to checkpoints/weights.72.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5388 - accuracy: 0.7383
# Epoch 73/200
# 800/804 [============================>.] - ETA: 0s - loss: 0.5389 - accuracy: 0.7380
# Epoch 73: saving model to checkpoints/weights.73.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5385 - accuracy: 0.7383
# Epoch 74/200
# 798/804 [============================>.] - ETA: 0s - loss: 0.5382 - accuracy: 0.7374
# Epoch 74: saving model to checkpoints/weights.74.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5383 - accuracy: 0.7374
# Epoch 75/200
# 803/804 [============================>.] - ETA: 0s - loss: 0.5384 - accuracy: 0.7379
# Epoch 75: saving model to checkpoints/weights.75.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5383 - accuracy: 0.7379
# Epoch 76/200
# 795/804 [============================>.] - ETA: 0s - loss: 0.5381 - accuracy: 0.7382
# Epoch 76: saving model to checkpoints/weights.76.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5382 - accuracy: 0.7384
# Epoch 77/200
# 788/804 [============================>.] - ETA: 0s - loss: 0.5390 - accuracy: 0.7386
# Epoch 77: saving model to checkpoints/weights.77.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5384 - accuracy: 0.7388
# Epoch 78/200
# 794/804 [============================>.] - ETA: 0s - loss: 0.5381 - accuracy: 0.7383
# Epoch 78: saving model to checkpoints/weights.78.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5383 - accuracy: 0.7385
# Epoch 79/200
# 782/804 [============================>.] - ETA: 0s - loss: 0.5383 - accuracy: 0.7385
# Epoch 79: saving model to checkpoints/weights.79.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5379 - accuracy: 0.7388
# Epoch 80/200
# 794/804 [============================>.] - ETA: 0s - loss: 0.5377 - accuracy: 0.7385
# Epoch 80: saving model to checkpoints/weights.80.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5381 - accuracy: 0.7386
# Epoch 81/200
# 802/804 [============================>.] - ETA: 0s - loss: 0.5378 - accuracy: 0.7385
# Epoch 81: saving model to checkpoints/weights.81.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5379 - accuracy: 0.7385
# Epoch 82/200
# 796/804 [============================>.] - ETA: 0s - loss: 0.5379 - accuracy: 0.7382
# Epoch 82: saving model to checkpoints/weights.82.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5382 - accuracy: 0.7382
# Epoch 83/200
# 791/804 [============================>.] - ETA: 0s - loss: 0.5387 - accuracy: 0.7376
# Epoch 83: saving model to checkpoints/weights.83.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5380 - accuracy: 0.7382
# Epoch 84/200
# 791/804 [============================>.] - ETA: 0s - loss: 0.5380 - accuracy: 0.7384
# Epoch 84: saving model to checkpoints/weights.84.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5382 - accuracy: 0.7386
# Epoch 85/200
# 794/804 [============================>.] - ETA: 0s - loss: 0.5378 - accuracy: 0.7386
# Epoch 85: saving model to checkpoints/weights.85.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5381 - accuracy: 0.7383
# Epoch 86/200
# 800/804 [============================>.] - ETA: 0s - loss: 0.5375 - accuracy: 0.7383
# Epoch 86: saving model to checkpoints/weights.86.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5374 - accuracy: 0.7382
# Epoch 87/200
# 783/804 [============================>.] - ETA: 0s - loss: 0.5377 - accuracy: 0.7387
# Epoch 87: saving model to checkpoints/weights.87.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5379 - accuracy: 0.7387
# Epoch 88/200
# 783/804 [============================>.] - ETA: 0s - loss: 0.5379 - accuracy: 0.7387
# Epoch 88: saving model to checkpoints/weights.88.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5378 - accuracy: 0.7388
# Epoch 89/200
# 795/804 [============================>.] - ETA: 0s - loss: 0.5387 - accuracy: 0.7379
# Epoch 89: saving model to checkpoints/weights.89.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5383 - accuracy: 0.7381
# Epoch 90/200
# 803/804 [============================>.] - ETA: 0s - loss: 0.5382 - accuracy: 0.7386
# Epoch 90: saving model to checkpoints/weights.90.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5379 - accuracy: 0.7388
# Epoch 91/200
# 781/804 [============================>.] - ETA: 0s - loss: 0.5380 - accuracy: 0.7384
# Epoch 91: saving model to checkpoints/weights.91.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5377 - accuracy: 0.7385
# Epoch 92/200
# 804/804 [==============================] - ETA: 0s - loss: 0.5375 - accuracy: 0.7386
# Epoch 92: saving model to checkpoints/weights.92.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5375 - accuracy: 0.7386
# Epoch 93/200
# 802/804 [============================>.] - ETA: 0s - loss: 0.5371 - accuracy: 0.7386
# Epoch 93: saving model to checkpoints/weights.93.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5372 - accuracy: 0.7386
# Epoch 94/200
# 792/804 [============================>.] - ETA: 0s - loss: 0.5372 - accuracy: 0.7389
# Epoch 94: saving model to checkpoints/weights.94.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5374 - accuracy: 0.7386
# Epoch 95/200
# 778/804 [============================>.] - ETA: 0s - loss: 0.5375 - accuracy: 0.7387
# Epoch 95: saving model to checkpoints/weights.95.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5374 - accuracy: 0.7388
# Epoch 96/200
# 798/804 [============================>.] - ETA: 0s - loss: 0.5371 - accuracy: 0.7389
# Epoch 96: saving model to checkpoints/weights.96.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5376 - accuracy: 0.7386
# Epoch 97/200
# 795/804 [============================>.] - ETA: 0s - loss: 0.5378 - accuracy: 0.7379
# Epoch 97: saving model to checkpoints/weights.97.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5374 - accuracy: 0.7379
# Epoch 98/200
# 804/804 [==============================] - ETA: 0s - loss: 0.5371 - accuracy: 0.7395
# Epoch 98: saving model to checkpoints/weights.98.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5371 - accuracy: 0.7395
# Epoch 99/200
# 787/804 [============================>.] - ETA: 0s - loss: 0.5375 - accuracy: 0.7383
# Epoch 99: saving model to checkpoints/weights.99.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5372 - accuracy: 0.7388
# Epoch 100/200
# 776/804 [===========================>..] - ETA: 0s - loss: 0.5365 - accuracy: 0.7397
# Epoch 100: saving model to checkpoints/weights.100.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5372 - accuracy: 0.7390
# Epoch 101/200
# 796/804 [============================>.] - ETA: 0s - loss: 0.5376 - accuracy: 0.7385
# Epoch 101: saving model to checkpoints/weights.101.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5377 - accuracy: 0.7385
# Epoch 102/200
# 789/804 [============================>.] - ETA: 0s - loss: 0.5376 - accuracy: 0.7388
# Epoch 102: saving model to checkpoints/weights.102.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5371 - accuracy: 0.7396
# Epoch 103/200
# 789/804 [============================>.] - ETA: 0s - loss: 0.5368 - accuracy: 0.7397
# Epoch 103: saving model to checkpoints/weights.103.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5370 - accuracy: 0.7393
# Epoch 104/200
# 795/804 [============================>.] - ETA: 0s - loss: 0.5372 - accuracy: 0.7384
# Epoch 104: saving model to checkpoints/weights.104.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5374 - accuracy: 0.7385
# Epoch 105/200
# 796/804 [============================>.] - ETA: 0s - loss: 0.5372 - accuracy: 0.7383
# Epoch 105: saving model to checkpoints/weights.105.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5370 - accuracy: 0.7386
# Epoch 106/200
# 785/804 [============================>.] - ETA: 0s - loss: 0.5379 - accuracy: 0.7382
# Epoch 106: saving model to checkpoints/weights.106.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5372 - accuracy: 0.7387
# Epoch 107/200
# 789/804 [============================>.] - ETA: 0s - loss: 0.5375 - accuracy: 0.7380
# Epoch 107: saving model to checkpoints/weights.107.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5370 - accuracy: 0.7385
# Epoch 108/200
# 801/804 [============================>.] - ETA: 0s - loss: 0.5371 - accuracy: 0.7382
# Epoch 108: saving model to checkpoints/weights.108.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5372 - accuracy: 0.7381
# Epoch 109/200
# 802/804 [============================>.] - ETA: 0s - loss: 0.5375 - accuracy: 0.7384
# Epoch 109: saving model to checkpoints/weights.109.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5372 - accuracy: 0.7385
# Epoch 110/200
# 790/804 [============================>.] - ETA: 0s - loss: 0.5363 - accuracy: 0.7398
# Epoch 110: saving model to checkpoints/weights.110.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5369 - accuracy: 0.7393
# Epoch 111/200
# 778/804 [============================>.] - ETA: 0s - loss: 0.5358 - accuracy: 0.7396
# Epoch 111: saving model to checkpoints/weights.111.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5370 - accuracy: 0.7390
# Epoch 112/200
# 783/804 [============================>.] - ETA: 0s - loss: 0.5367 - accuracy: 0.7391
# Epoch 112: saving model to checkpoints/weights.112.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5369 - accuracy: 0.7390
# Epoch 113/200
# 796/804 [============================>.] - ETA: 0s - loss: 0.5361 - accuracy: 0.7393
# Epoch 113: saving model to checkpoints/weights.113.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5367 - accuracy: 0.7387
# Epoch 114/200
# 802/804 [============================>.] - ETA: 0s - loss: 0.5366 - accuracy: 0.7387
# Epoch 114: saving model to checkpoints/weights.114.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5365 - accuracy: 0.7388
# Epoch 115/200
# 803/804 [============================>.] - ETA: 0s - loss: 0.5365 - accuracy: 0.7385
# Epoch 115: saving model to checkpoints/weights.115.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5366 - accuracy: 0.7384
# Epoch 116/200
# 797/804 [============================>.] - ETA: 0s - loss: 0.5368 - accuracy: 0.7385
# Epoch 116: saving model to checkpoints/weights.116.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5368 - accuracy: 0.7386
# Epoch 117/200
# 793/804 [============================>.] - ETA: 0s - loss: 0.5372 - accuracy: 0.7393
# Epoch 117: saving model to checkpoints/weights.117.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5368 - accuracy: 0.7396
# Epoch 118/200
# 783/804 [============================>.] - ETA: 0s - loss: 0.5364 - accuracy: 0.7392
# Epoch 118: saving model to checkpoints/weights.118.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5365 - accuracy: 0.7392
# Epoch 119/200
# 789/804 [============================>.] - ETA: 0s - loss: 0.5366 - accuracy: 0.7389
# Epoch 119: saving model to checkpoints/weights.119.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5368 - accuracy: 0.7385
# Epoch 120/200
# 792/804 [============================>.] - ETA: 0s - loss: 0.5367 - accuracy: 0.7398
# Epoch 120: saving model to checkpoints/weights.120.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5370 - accuracy: 0.7395
# Epoch 121/200
# 803/804 [============================>.] - ETA: 0s - loss: 0.5363 - accuracy: 0.7393
# Epoch 121: saving model to checkpoints/weights.121.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5366 - accuracy: 0.7392
# Epoch 122/200
# 801/804 [============================>.] - ETA: 0s - loss: 0.5367 - accuracy: 0.7392
# Epoch 122: saving model to checkpoints/weights.122.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5367 - accuracy: 0.7391
# Epoch 123/200
# 801/804 [============================>.] - ETA: 0s - loss: 0.5370 - accuracy: 0.7388
# Epoch 123: saving model to checkpoints/weights.123.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5370 - accuracy: 0.7388
# Epoch 124/200
# 785/804 [============================>.] - ETA: 0s - loss: 0.5370 - accuracy: 0.7387
# Epoch 124: saving model to checkpoints/weights.124.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5365 - accuracy: 0.7390
# Epoch 125/200
# 779/804 [============================>.] - ETA: 0s - loss: 0.5362 - accuracy: 0.7385
# Epoch 125: saving model to checkpoints/weights.125.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5361 - accuracy: 0.7386
# Epoch 126/200
# 798/804 [============================>.] - ETA: 0s - loss: 0.5369 - accuracy: 0.7386
# Epoch 126: saving model to checkpoints/weights.126.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5365 - accuracy: 0.7388
# Epoch 127/200
# 788/804 [============================>.] - ETA: 0s - loss: 0.5371 - accuracy: 0.7378
# Epoch 127: saving model to checkpoints/weights.127.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5365 - accuracy: 0.7388
# Epoch 128/200
# 804/804 [==============================] - ETA: 0s - loss: 0.5362 - accuracy: 0.7395
# Epoch 128: saving model to checkpoints/weights.128.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5362 - accuracy: 0.7395
# Epoch 129/200
# 791/804 [============================>.] - ETA: 0s - loss: 0.5363 - accuracy: 0.7392
# Epoch 129: saving model to checkpoints/weights.129.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5368 - accuracy: 0.7390
# Epoch 130/200
# 778/804 [============================>.] - ETA: 0s - loss: 0.5358 - accuracy: 0.7396
# Epoch 130: saving model to checkpoints/weights.130.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5363 - accuracy: 0.7395
# Epoch 131/200
# 779/804 [============================>.] - ETA: 0s - loss: 0.5362 - accuracy: 0.7401
# Epoch 131: saving model to checkpoints/weights.131.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5361 - accuracy: 0.7400
# Epoch 132/200
# 798/804 [============================>.] - ETA: 0s - loss: 0.5360 - accuracy: 0.7395
# Epoch 132: saving model to checkpoints/weights.132.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5359 - accuracy: 0.7395
# Epoch 133/200
# 792/804 [============================>.] - ETA: 0s - loss: 0.5354 - accuracy: 0.7401
# Epoch 133: saving model to checkpoints/weights.133.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5363 - accuracy: 0.7396
# Epoch 134/200
# 785/804 [============================>.] - ETA: 0s - loss: 0.5357 - accuracy: 0.7395
# Epoch 134: saving model to checkpoints/weights.134.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5362 - accuracy: 0.7395
# Epoch 135/200
# 779/804 [============================>.] - ETA: 0s - loss: 0.5361 - accuracy: 0.7392
# Epoch 135: saving model to checkpoints/weights.135.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5360 - accuracy: 0.7389
# Epoch 136/200
# 787/804 [============================>.] - ETA: 0s - loss: 0.5360 - accuracy: 0.7388
# Epoch 136: saving model to checkpoints/weights.136.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5359 - accuracy: 0.7393
# Epoch 137/200
# 790/804 [============================>.] - ETA: 0s - loss: 0.5366 - accuracy: 0.7389
# Epoch 137: saving model to checkpoints/weights.137.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5361 - accuracy: 0.7394
# Epoch 138/200
# 803/804 [============================>.] - ETA: 0s - loss: 0.5361 - accuracy: 0.7385
# Epoch 138: saving model to checkpoints/weights.138.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5359 - accuracy: 0.7386
# Epoch 139/200
# 794/804 [============================>.] - ETA: 0s - loss: 0.5364 - accuracy: 0.7393
# Epoch 139: saving model to checkpoints/weights.139.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5360 - accuracy: 0.7398
# Epoch 140/200
# 788/804 [============================>.] - ETA: 0s - loss: 0.5360 - accuracy: 0.7395
# Epoch 140: saving model to checkpoints/weights.140.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5361 - accuracy: 0.7394
# Epoch 141/200
# 804/804 [==============================] - ETA: 0s - loss: 0.5361 - accuracy: 0.7390
# Epoch 141: saving model to checkpoints/weights.141.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5361 - accuracy: 0.7390
# Epoch 142/200
# 787/804 [============================>.] - ETA: 0s - loss: 0.5350 - accuracy: 0.7399
# Epoch 142: saving model to checkpoints/weights.142.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5358 - accuracy: 0.7392
# Epoch 143/200
# 796/804 [============================>.] - ETA: 0s - loss: 0.5361 - accuracy: 0.7388
# Epoch 143: saving model to checkpoints/weights.143.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5358 - accuracy: 0.7390
# Epoch 144/200
# 790/804 [============================>.] - ETA: 0s - loss: 0.5368 - accuracy: 0.7381
# Epoch 144: saving model to checkpoints/weights.144.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5359 - accuracy: 0.7388
# Epoch 145/200
# 802/804 [============================>.] - ETA: 0s - loss: 0.5361 - accuracy: 0.7392
# Epoch 145: saving model to checkpoints/weights.145.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5360 - accuracy: 0.7393
# Epoch 146/200
# 790/804 [============================>.] - ETA: 0s - loss: 0.5353 - accuracy: 0.7396
# Epoch 146: saving model to checkpoints/weights.146.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5360 - accuracy: 0.7390
# Epoch 147/200
# 792/804 [============================>.] - ETA: 0s - loss: 0.5365 - accuracy: 0.7391
# Epoch 147: saving model to checkpoints/weights.147.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5364 - accuracy: 0.7389
# Epoch 148/200
# 785/804 [============================>.] - ETA: 0s - loss: 0.5356 - accuracy: 0.7402
# Epoch 148: saving model to checkpoints/weights.148.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5361 - accuracy: 0.7397
# Epoch 149/200
# 795/804 [============================>.] - ETA: 0s - loss: 0.5364 - accuracy: 0.7397
# Epoch 149: saving model to checkpoints/weights.149.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5364 - accuracy: 0.7394
# Epoch 150/200
# 780/804 [============================>.] - ETA: 0s - loss: 0.5355 - accuracy: 0.7399
# Epoch 150: saving model to checkpoints/weights.150.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5359 - accuracy: 0.7395
# Epoch 151/200
# 791/804 [============================>.] - ETA: 0s - loss: 0.5362 - accuracy: 0.7382
# Epoch 151: saving model to checkpoints/weights.151.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5360 - accuracy: 0.7384
# Epoch 152/200
# 795/804 [============================>.] - ETA: 0s - loss: 0.5359 - accuracy: 0.7391
# Epoch 152: saving model to checkpoints/weights.152.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5359 - accuracy: 0.7392
# Epoch 153/200
# 796/804 [============================>.] - ETA: 0s - loss: 0.5349 - accuracy: 0.7407
# Epoch 153: saving model to checkpoints/weights.153.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5358 - accuracy: 0.7400
# Epoch 154/200
# 803/804 [============================>.] - ETA: 0s - loss: 0.5360 - accuracy: 0.7393
# Epoch 154: saving model to checkpoints/weights.154.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5359 - accuracy: 0.7394
# Epoch 155/200
# 793/804 [============================>.] - ETA: 0s - loss: 0.5353 - accuracy: 0.7392
# Epoch 155: saving model to checkpoints/weights.155.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5356 - accuracy: 0.7392
# Epoch 156/200
# 802/804 [============================>.] - ETA: 0s - loss: 0.5356 - accuracy: 0.7389
# Epoch 156: saving model to checkpoints/weights.156.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5356 - accuracy: 0.7390
# Epoch 157/200
# 779/804 [============================>.] - ETA: 0s - loss: 0.5345 - accuracy: 0.7411
# Epoch 157: saving model to checkpoints/weights.157.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5356 - accuracy: 0.7400
# Epoch 158/200
# 786/804 [============================>.] - ETA: 0s - loss: 0.5363 - accuracy: 0.7391
# Epoch 158: saving model to checkpoints/weights.158.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5360 - accuracy: 0.7392
# Epoch 159/200
# 780/804 [============================>.] - ETA: 0s - loss: 0.5350 - accuracy: 0.7393
# Epoch 159: saving model to checkpoints/weights.159.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5356 - accuracy: 0.7386
# Epoch 160/200
# 792/804 [============================>.] - ETA: 0s - loss: 0.5356 - accuracy: 0.7402
# Epoch 160: saving model to checkpoints/weights.160.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5357 - accuracy: 0.7400
# Epoch 161/200
# 789/804 [============================>.] - ETA: 0s - loss: 0.5353 - accuracy: 0.7395
# Epoch 161: saving model to checkpoints/weights.161.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5356 - accuracy: 0.7393
# Epoch 162/200
# 782/804 [============================>.] - ETA: 0s - loss: 0.5346 - accuracy: 0.7394
# Epoch 162: saving model to checkpoints/weights.162.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5354 - accuracy: 0.7390
# Epoch 163/200
# 801/804 [============================>.] - ETA: 0s - loss: 0.5356 - accuracy: 0.7395
# Epoch 163: saving model to checkpoints/weights.163.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5356 - accuracy: 0.7395
# Epoch 164/200
# 803/804 [============================>.] - ETA: 0s - loss: 0.5357 - accuracy: 0.7389
# Epoch 164: saving model to checkpoints/weights.164.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5357 - accuracy: 0.7389
# Epoch 165/200
# 779/804 [============================>.] - ETA: 0s - loss: 0.5349 - accuracy: 0.7400
# Epoch 165: saving model to checkpoints/weights.165.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5354 - accuracy: 0.7391
# Epoch 166/200
# 778/804 [============================>.] - ETA: 0s - loss: 0.5357 - accuracy: 0.7398
# Epoch 166: saving model to checkpoints/weights.166.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5355 - accuracy: 0.7396
# Epoch 167/200
# 799/804 [============================>.] - ETA: 0s - loss: 0.5356 - accuracy: 0.7392
# Epoch 167: saving model to checkpoints/weights.167.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5352 - accuracy: 0.7394
# Epoch 168/200
# 784/804 [============================>.] - ETA: 0s - loss: 0.5349 - accuracy: 0.7395
# Epoch 168: saving model to checkpoints/weights.168.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5354 - accuracy: 0.7392
# Epoch 169/200
# 795/804 [============================>.] - ETA: 0s - loss: 0.5351 - accuracy: 0.7396
# Epoch 169: saving model to checkpoints/weights.169.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5351 - accuracy: 0.7394
# Epoch 170/200
# 778/804 [============================>.] - ETA: 0s - loss: 0.5351 - accuracy: 0.7390
# Epoch 170: saving model to checkpoints/weights.170.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5353 - accuracy: 0.7391
# Epoch 171/200
# 803/804 [============================>.] - ETA: 0s - loss: 0.5357 - accuracy: 0.7392
# Epoch 171: saving model to checkpoints/weights.171.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5357 - accuracy: 0.7392
# Epoch 172/200
# 777/804 [===========================>..] - ETA: 0s - loss: 0.5351 - accuracy: 0.7402
# Epoch 172: saving model to checkpoints/weights.172.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5351 - accuracy: 0.7396
# Epoch 173/200
# 803/804 [============================>.] - ETA: 0s - loss: 0.5352 - accuracy: 0.7394
# Epoch 173: saving model to checkpoints/weights.173.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5354 - accuracy: 0.7392
# Epoch 174/200
# 792/804 [============================>.] - ETA: 0s - loss: 0.5356 - accuracy: 0.7390
# Epoch 174: saving model to checkpoints/weights.174.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5355 - accuracy: 0.7392
# Epoch 175/200
# 792/804 [============================>.] - ETA: 0s - loss: 0.5354 - accuracy: 0.7393
# Epoch 175: saving model to checkpoints/weights.175.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5354 - accuracy: 0.7393
# Epoch 176/200
# 785/804 [============================>.] - ETA: 0s - loss: 0.5353 - accuracy: 0.7393
# Epoch 176: saving model to checkpoints/weights.176.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5354 - accuracy: 0.7395
# Epoch 177/200
# 790/804 [============================>.] - ETA: 0s - loss: 0.5353 - accuracy: 0.7396
# Epoch 177: saving model to checkpoints/weights.177.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5353 - accuracy: 0.7394
# Epoch 178/200
# 782/804 [============================>.] - ETA: 0s - loss: 0.5345 - accuracy: 0.7401
# Epoch 178: saving model to checkpoints/weights.178.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5356 - accuracy: 0.7398
# Epoch 179/200
# 786/804 [============================>.] - ETA: 0s - loss: 0.5347 - accuracy: 0.7388
# Epoch 179: saving model to checkpoints/weights.179.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5352 - accuracy: 0.7382
# Epoch 180/200
# 793/804 [============================>.] - ETA: 0s - loss: 0.5349 - accuracy: 0.7398
# Epoch 180: saving model to checkpoints/weights.180.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5351 - accuracy: 0.7398
# Epoch 181/200
# 786/804 [============================>.] - ETA: 0s - loss: 0.5353 - accuracy: 0.7395
# Epoch 181: saving model to checkpoints/weights.181.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5360 - accuracy: 0.7390
# Epoch 182/200
# 792/804 [============================>.] - ETA: 0s - loss: 0.5350 - accuracy: 0.7395
# Epoch 182: saving model to checkpoints/weights.182.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5355 - accuracy: 0.7392
# Epoch 183/200
# 798/804 [============================>.] - ETA: 0s - loss: 0.5353 - accuracy: 0.7401
# Epoch 183: saving model to checkpoints/weights.183.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5358 - accuracy: 0.7399
# Epoch 184/200
# 779/804 [============================>.] - ETA: 0s - loss: 0.5351 - accuracy: 0.7404
# Epoch 184: saving model to checkpoints/weights.184.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5347 - accuracy: 0.7404
# Epoch 185/200
# 780/804 [============================>.] - ETA: 0s - loss: 0.5352 - accuracy: 0.7389
# Epoch 185: saving model to checkpoints/weights.185.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5349 - accuracy: 0.7392
# Epoch 186/200
# 782/804 [============================>.] - ETA: 0s - loss: 0.5352 - accuracy: 0.7393
# Epoch 186: saving model to checkpoints/weights.186.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5350 - accuracy: 0.7394
# Epoch 187/200
# 798/804 [============================>.] - ETA: 0s - loss: 0.5350 - accuracy: 0.7387
# Epoch 187: saving model to checkpoints/weights.187.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5354 - accuracy: 0.7385
# Epoch 188/200
# 801/804 [============================>.] - ETA: 0s - loss: 0.5351 - accuracy: 0.7391
# Epoch 188: saving model to checkpoints/weights.188.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5352 - accuracy: 0.7390
# Epoch 189/200
# 793/804 [============================>.] - ETA: 0s - loss: 0.5351 - accuracy: 0.7395
# Epoch 189: saving model to checkpoints/weights.189.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5350 - accuracy: 0.7395
# Epoch 190/200
# 787/804 [============================>.] - ETA: 0s - loss: 0.5346 - accuracy: 0.7400
# Epoch 190: saving model to checkpoints/weights.190.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5349 - accuracy: 0.7397
# Epoch 191/200
# 793/804 [============================>.] - ETA: 0s - loss: 0.5356 - accuracy: 0.7388
# Epoch 191: saving model to checkpoints/weights.191.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5350 - accuracy: 0.7395
# Epoch 192/200
# 787/804 [============================>.] - ETA: 0s - loss: 0.5350 - accuracy: 0.7387
# Epoch 192: saving model to checkpoints/weights.192.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5350 - accuracy: 0.7389
# Epoch 193/200
# 799/804 [============================>.] - ETA: 0s - loss: 0.5358 - accuracy: 0.7402
# Epoch 193: saving model to checkpoints/weights.193.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5357 - accuracy: 0.7403
# Epoch 194/200
# 797/804 [============================>.] - ETA: 0s - loss: 0.5349 - accuracy: 0.7398
# Epoch 194: saving model to checkpoints/weights.194.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5348 - accuracy: 0.7398
# Epoch 195/200
# 781/804 [============================>.] - ETA: 0s - loss: 0.5346 - accuracy: 0.7404
# Epoch 195: saving model to checkpoints/weights.195.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5349 - accuracy: 0.7399
# Epoch 196/200
# 794/804 [============================>.] - ETA: 0s - loss: 0.5357 - accuracy: 0.7385
# Epoch 196: saving model to checkpoints/weights.196.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5348 - accuracy: 0.7396
# Epoch 197/200
# 800/804 [============================>.] - ETA: 0s - loss: 0.5353 - accuracy: 0.7396
# Epoch 197: saving model to checkpoints/weights.197.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5351 - accuracy: 0.7398
# Epoch 198/200
# 786/804 [============================>.] - ETA: 0s - loss: 0.5343 - accuracy: 0.7399
# Epoch 198: saving model to checkpoints/weights.198.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5346 - accuracy: 0.7397
# Epoch 199/200
# 791/804 [============================>.] - ETA: 0s - loss: 0.5336 - accuracy: 0.7413
# Epoch 199: saving model to checkpoints/weights.199.hdf5
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5347 - accuracy: 0.7404
# Epoch 200/200
# 792/804 [============================>.] - ETA: 0s - loss: 0.5349 - accuracy: 0.7391
# Epoch 200: saving model to checkpoints/weights.200.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5347 - accuracy: 0.7393

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5584 - accuracy: 0.7318 - 430ms/epoch - 2ms/step
# Loss: 0.5583990812301636, Accuracy: 0.7317784428596497

# %% [markdown]
# Additional Nodes

# %%
#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://raw.githubusercontent.com/slstapleton/Neural_Network_Charity_Analysis/main/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(labels=["EIN", "NAME", "SPECIAL_CONSIDERATIONS"], axis=1)

# %%
# Look at APPLICATION_TYPE value counts for binning
application_counts = application_df.APPLICATION_TYPE.value_counts()

# Determine which values to replace if counts are less than ...?
replace_application = list(application_counts[application_counts < 500].index)

# Replace in dataframe
for app in replace_application:
    application_df.APPLICATION_TYPE = application_df.APPLICATION_TYPE.replace(app,"Other")

# %%
# Look at CLASSIFICATION value counts for binning
class_counts = application_df.CLASSIFICATION.value_counts()

# Determine which values to replace if counts are less than ..?
replace_class = list(class_counts[class_counts < 1800].index)

# Replace in dataframe
for cls in replace_class:
    application_df.CLASSIFICATION = application_df.CLASSIFICATION.replace(cls,"Other")

# %%
# Generate our categorical variable lists
application_cat = list(application_df.dtypes[application_df.dtypes == "object"].index)

# %%
# Create a OneHotEncoder instance
enc = OneHotEncoder(sparse=False)

# Fit and transform the OneHotEncoder using the categorical variable list
encode_df = pd.DataFrame(enc.fit_transform(application_df[application_cat]))

# Add the encoded variable names to the dataframe
encode_df.columns = enc.get_feature_names(application_cat)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Merge one-hot encoded features and drop the originals
application_df = application_df.merge(encode_df, left_index=True, right_index=True)
application_df = application_df.drop(labels=application_cat, axis=1)

# %%
# Split our preprocessed data into our features and target arrays
y = application_df["IS_SUCCESSFUL"].values.reshape(-1, 1)
X = application_df.drop("IS_SUCCESSFUL", axis=1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 30
hidden_nodes_layer3 = 10
hidden_nodes_layer4 = 2

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="sigmoid"))

# Fourth hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="linear"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 80)                3360
#
#  dense_4 (Dense)             (None, 30)                2430
#
#  dense_5 (Dense)             (None, 10)                310
#
#  dense_6 (Dense)             (None, 10)                110
#
#  dense_7 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 6,221
# Trainable params: 6,221
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Add model weight checkpoints during training
import os
from tensorflow.keras.callbacks import ModelCheckpoint
os.makedirs("checkpoints/", exist_ok=True)
checkpoint_path="checkpoints/weights.{epoch}.hdf5"

# Create a callback that saves the model's weights every epoch
cp_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=5,
    save_weights_only=True,
    save_freq='epoch')

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100,callbacks=[cp_callback])
# Out:
# Epoch 1/100
# 798/804 [============================>.] - ETA: 0s - loss: 0.5537 - accuracy: 0.7296
# Epoch 1: saving model to checkpoints/weights.1.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5536 - accuracy: 0.7297
# Epoch 2/100
# 789/804 [============================>.] - ETA: 0s - loss: 0.5518 - accuracy: 0.7305
# Epoch 2: saving model to checkpoints/weights.2.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5526 - accuracy: 0.7299
# Epoch 3/100
# 783/804 [============================>.] - ETA: 0s - loss: 0.5516 - accuracy: 0.7302
# Epoch 3: saving model to checkpoints/weights.3.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5514 - accuracy: 0.7304
# Epoch 4/100
# 803/804 [============================>.] - ETA: 0s - loss: 0.5501 - accuracy: 0.7311
# Epoch 4: saving model to checkpoints/weights.4.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5501 - accuracy: 0.7312
# Epoch 5/100
# 802/804 [============================>.] - ETA: 0s - loss: 0.5493 - accuracy: 0.7320
# Epoch 5: saving model to checkpoints/weights.5.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5493 - accuracy: 0.7320
# Epoch 6/100
# 780/804 [============================>.] - ETA: 0s - loss: 0.5487 - accuracy: 0.7327
# Epoch 6: saving model to checkpoints/weights.6.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5490 - accuracy: 0.7323
# Epoch 7/100
# 792/804 [============================>.] - ETA: 0s - loss: 0.5491 - accuracy: 0.7319
# Epoch 7: saving model to checkpoints/weights.7.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5489 - accuracy: 0.7318
# Epoch 8/100
# 795/804 [============================>.] - ETA: 0s - loss: 0.5481 - accuracy: 0.7319
# Epoch 8: saving model to checkpoints/weights.8.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5479 - accuracy: 0.7319
# Epoch 9/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.5471 - accuracy: 0.7340
# Epoch 9: saving model to checkpoints/weights.9.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5472 - accuracy: 0.7339
# Epoch 10/100
# 787/804 [============================>.] - ETA: 0s - loss: 0.5465 - accuracy: 0.7320
# Epoch 10: saving model to checkpoints/weights.10.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5465 - accuracy: 0.7320
# Epoch 11/100
# 794/804 [============================>.] - ETA: 0s - loss: 0.5465 - accuracy: 0.7329
# Epoch 11: saving model to checkpoints/weights.11.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5460 - accuracy: 0.7332
# Epoch 12/100
# 789/804 [============================>.] - ETA: 0s - loss: 0.5463 - accuracy: 0.7340
# Epoch 12: saving model to checkpoints/weights.12.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5461 - accuracy: 0.7343
# Epoch 13/100
# 791/804 [============================>.] - ETA: 0s - loss: 0.5454 - accuracy: 0.7344
# Epoch 13: saving model to checkpoints/weights.13.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5457 - accuracy: 0.7341
# Epoch 14/100
# 787/804 [============================>.] - ETA: 0s - loss: 0.5466 - accuracy: 0.7339
# Epoch 14: saving model to checkpoints/weights.14.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5460 - accuracy: 0.7344
# Epoch 15/100
# 778/804 [============================>.] - ETA: 0s - loss: 0.5458 - accuracy: 0.7344
# Epoch 15: saving model to checkpoints/weights.15.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5456 - accuracy: 0.7348
# Epoch 16/100
# 804/804 [==============================] - ETA: 0s - loss: 0.5451 - accuracy: 0.7330
# Epoch 16: saving model to checkpoints/weights.16.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5451 - accuracy: 0.7330
# Epoch 17/100
# 778/804 [============================>.] - ETA: 0s - loss: 0.5449 - accuracy: 0.7348
# Epoch 17: saving model to checkpoints/weights.17.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5448 - accuracy: 0.7346
# Epoch 18/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.5445 - accuracy: 0.7345
# Epoch 18: saving model to checkpoints/weights.18.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5447 - accuracy: 0.7343
# Epoch 19/100
# 790/804 [============================>.] - ETA: 0s - loss: 0.5442 - accuracy: 0.7348
# Epoch 19: saving model to checkpoints/weights.19.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5444 - accuracy: 0.7341
# Epoch 20/100
# 794/804 [============================>.] - ETA: 0s - loss: 0.5443 - accuracy: 0.7351
# Epoch 20: saving model to checkpoints/weights.20.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5444 - accuracy: 0.7348
# Epoch 21/100
# 799/804 [============================>.] - ETA: 0s - loss: 0.5443 - accuracy: 0.7355
# Epoch 21: saving model to checkpoints/weights.21.hdf5
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5440 - accuracy: 0.7358
# Epoch 22/100
# 784/804 [============================>.] - ETA: 0s - loss: 0.5430 - accuracy: 0.7367
# Epoch 22: saving model to checkpoints/weights.22.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5434 - accuracy: 0.7363
# Epoch 23/100
# 781/804 [============================>.] - ETA: 0s - loss: 0.5431 - accuracy: 0.7350
# Epoch 23: saving model to checkpoints/weights.23.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5431 - accuracy: 0.7348
# Epoch 24/100
# 799/804 [============================>.] - ETA: 0s - loss: 0.5433 - accuracy: 0.7347
# Epoch 24: saving model to checkpoints/weights.24.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5433 - accuracy: 0.7346
# Epoch 25/100
# 796/804 [============================>.] - ETA: 0s - loss: 0.5426 - accuracy: 0.7354
# Epoch 25: saving model to checkpoints/weights.25.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5431 - accuracy: 0.7349
# Epoch 26/100
# 786/804 [============================>.] - ETA: 0s - loss: 0.5427 - accuracy: 0.7352
# Epoch 26: saving model to checkpoints/weights.26.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5426 - accuracy: 0.7353
# Epoch 27/100
# 799/804 [============================>.] - ETA: 0s - loss: 0.5427 - accuracy: 0.7361
# Epoch 27: saving model to checkpoints/weights.27.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5427 - accuracy: 0.7360
# Epoch 28/100
# 794/804 [============================>.] - ETA: 0s - loss: 0.5426 - accuracy: 0.7348
# Epoch 28: saving model to checkpoints/weights.28.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5426 - accuracy: 0.7348
# Epoch 29/100
# 804/804 [==============================] - ETA: 0s - loss: 0.5423 - accuracy: 0.7365
# Epoch 29: saving model to checkpoints/weights.29.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5423 - accuracy: 0.7365
# Epoch 30/100
# 804/804 [==============================] - ETA: 0s - loss: 0.5419 - accuracy: 0.7369
# Epoch 30: saving model to checkpoints/weights.30.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5419 - accuracy: 0.7369
# Epoch 31/100
# 800/804 [============================>.] - ETA: 0s - loss: 0.5418 - accuracy: 0.7356
# Epoch 31: saving model to checkpoints/weights.31.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5417 - accuracy: 0.7357
# Epoch 32/100
# 799/804 [============================>.] - ETA: 0s - loss: 0.5415 - accuracy: 0.7357
# Epoch 32: saving model to checkpoints/weights.32.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5416 - accuracy: 0.7357
# Epoch 33/100
# 788/804 [============================>.] - ETA: 0s - loss: 0.5423 - accuracy: 0.7362
# Epoch 33: saving model to checkpoints/weights.33.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5417 - accuracy: 0.7368
# Epoch 34/100
# 798/804 [============================>.] - ETA: 0s - loss: 0.5409 - accuracy: 0.7382
# Epoch 34: saving model to checkpoints/weights.34.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5414 - accuracy: 0.7377
# Epoch 35/100
# 796/804 [============================>.] - ETA: 0s - loss: 0.5415 - accuracy: 0.7366
# Epoch 35: saving model to checkpoints/weights.35.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5412 - accuracy: 0.7365
# Epoch 36/100
# 803/804 [============================>.] - ETA: 0s - loss: 0.5410 - accuracy: 0.7374
# Epoch 36: saving model to checkpoints/weights.36.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5410 - accuracy: 0.7373
# Epoch 37/100
# 798/804 [============================>.] - ETA: 0s - loss: 0.5411 - accuracy: 0.7376
# Epoch 37: saving model to checkpoints/weights.37.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5411 - accuracy: 0.7374
# Epoch 38/100
# 798/804 [============================>.] - ETA: 0s - loss: 0.5408 - accuracy: 0.7370
# Epoch 38: saving model to checkpoints/weights.38.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5407 - accuracy: 0.7371
# Epoch 39/100
# 796/804 [============================>.] - ETA: 0s - loss: 0.5404 - accuracy: 0.7364
# Epoch 39: saving model to checkpoints/weights.39.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5404 - accuracy: 0.7367
# Epoch 40/100
# 789/804 [============================>.] - ETA: 0s - loss: 0.5413 - accuracy: 0.7371
# Epoch 40: saving model to checkpoints/weights.40.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5406 - accuracy: 0.7378
# Epoch 41/100
# 798/804 [============================>.] - ETA: 0s - loss: 0.5403 - accuracy: 0.7366
# Epoch 41: saving model to checkpoints/weights.41.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5407 - accuracy: 0.7362
# Epoch 42/100
# 799/804 [============================>.] - ETA: 0s - loss: 0.5404 - accuracy: 0.7365
# Epoch 42: saving model to checkpoints/weights.42.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5403 - accuracy: 0.7366
# Epoch 43/100
# 804/804 [==============================] - ETA: 0s - loss: 0.5399 - accuracy: 0.7372
# Epoch 43: saving model to checkpoints/weights.43.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5399 - accuracy: 0.7372
# Epoch 44/100
# 796/804 [============================>.] - ETA: 0s - loss: 0.5398 - accuracy: 0.7377
# Epoch 44: saving model to checkpoints/weights.44.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5399 - accuracy: 0.7374
# Epoch 45/100
# 783/804 [============================>.] - ETA: 0s - loss: 0.5404 - accuracy: 0.7372
# Epoch 45: saving model to checkpoints/weights.45.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5397 - accuracy: 0.7375
# Epoch 46/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.5398 - accuracy: 0.7376
# Epoch 46: saving model to checkpoints/weights.46.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5398 - accuracy: 0.7375
# Epoch 47/100
# 779/804 [============================>.] - ETA: 0s - loss: 0.5402 - accuracy: 0.7380
# Epoch 47: saving model to checkpoints/weights.47.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5399 - accuracy: 0.7379
# Epoch 48/100
# 781/804 [============================>.] - ETA: 0s - loss: 0.5409 - accuracy: 0.7360
# Epoch 48: saving model to checkpoints/weights.48.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5396 - accuracy: 0.7372
# Epoch 49/100
# 787/804 [============================>.] - ETA: 0s - loss: 0.5398 - accuracy: 0.7373
# Epoch 49: saving model to checkpoints/weights.49.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5396 - accuracy: 0.7374
# Epoch 50/100
# 795/804 [============================>.] - ETA: 0s - loss: 0.5394 - accuracy: 0.7378
# Epoch 50: saving model to checkpoints/weights.50.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5395 - accuracy: 0.7378
# Epoch 51/100
# 780/804 [============================>.] - ETA: 0s - loss: 0.5406 - accuracy: 0.7363
# Epoch 51: saving model to checkpoints/weights.51.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5392 - accuracy: 0.7374
# Epoch 52/100
# 780/804 [============================>.] - ETA: 0s - loss: 0.5391 - accuracy: 0.7383
# Epoch 52: saving model to checkpoints/weights.52.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5393 - accuracy: 0.7381
# Epoch 53/100
# 795/804 [============================>.] - ETA: 0s - loss: 0.5386 - accuracy: 0.7371
# Epoch 53: saving model to checkpoints/weights.53.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5389 - accuracy: 0.7370
# Epoch 54/100
# 791/804 [============================>.] - ETA: 0s - loss: 0.5389 - accuracy: 0.7375
# Epoch 54: saving model to checkpoints/weights.54.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5391 - accuracy: 0.7374
# Epoch 55/100
# 791/804 [============================>.] - ETA: 0s - loss: 0.5386 - accuracy: 0.7389
# Epoch 55: saving model to checkpoints/weights.55.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5388 - accuracy: 0.7388
# Epoch 56/100
# 786/804 [============================>.] - ETA: 0s - loss: 0.5386 - accuracy: 0.7376
# Epoch 56: saving model to checkpoints/weights.56.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5386 - accuracy: 0.7374
# Epoch 57/100
# 798/804 [============================>.] - ETA: 0s - loss: 0.5386 - accuracy: 0.7388
# Epoch 57: saving model to checkpoints/weights.57.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5386 - accuracy: 0.7387
# Epoch 58/100
# 781/804 [============================>.] - ETA: 0s - loss: 0.5390 - accuracy: 0.7382
# Epoch 58: saving model to checkpoints/weights.58.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5385 - accuracy: 0.7382
# Epoch 59/100
# 781/804 [============================>.] - ETA: 0s - loss: 0.5377 - accuracy: 0.7394
# Epoch 59: saving model to checkpoints/weights.59.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5382 - accuracy: 0.7386
# Epoch 60/100
# 798/804 [============================>.] - ETA: 0s - loss: 0.5377 - accuracy: 0.7388
# Epoch 60: saving model to checkpoints/weights.60.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5380 - accuracy: 0.7387
# Epoch 61/100
# 803/804 [============================>.] - ETA: 0s - loss: 0.5382 - accuracy: 0.7381
# Epoch 61: saving model to checkpoints/weights.61.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5382 - accuracy: 0.7381
# Epoch 62/100
# 798/804 [============================>.] - ETA: 0s - loss: 0.5386 - accuracy: 0.7374
# Epoch 62: saving model to checkpoints/weights.62.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5382 - accuracy: 0.7379
# Epoch 63/100
# 784/804 [============================>.] - ETA: 0s - loss: 0.5389 - accuracy: 0.7380
# Epoch 63: saving model to checkpoints/weights.63.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5386 - accuracy: 0.7378
# Epoch 64/100
# 800/804 [============================>.] - ETA: 0s - loss: 0.5380 - accuracy: 0.7390
# Epoch 64: saving model to checkpoints/weights.64.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5382 - accuracy: 0.7391
# Epoch 65/100
# 793/804 [============================>.] - ETA: 0s - loss: 0.5381 - accuracy: 0.7385
# Epoch 65: saving model to checkpoints/weights.65.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5378 - accuracy: 0.7385
# Epoch 66/100
# 794/804 [============================>.] - ETA: 0s - loss: 0.5373 - accuracy: 0.7385
# Epoch 66: saving model to checkpoints/weights.66.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5378 - accuracy: 0.7380
# Epoch 67/100
# 798/804 [============================>.] - ETA: 0s - loss: 0.5375 - accuracy: 0.7384
# Epoch 67: saving model to checkpoints/weights.67.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5374 - accuracy: 0.7387
# Epoch 68/100
# 798/804 [============================>.] - ETA: 0s - loss: 0.5379 - accuracy: 0.7384
# Epoch 68: saving model to checkpoints/weights.68.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5377 - accuracy: 0.7384
# Epoch 69/100
# 787/804 [============================>.] - ETA: 0s - loss: 0.5375 - accuracy: 0.7377
# Epoch 69: saving model to checkpoints/weights.69.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5378 - accuracy: 0.7376
# Epoch 70/100
# 797/804 [============================>.] - ETA: 0s - loss: 0.5378 - accuracy: 0.7380
# Epoch 70: saving model to checkpoints/weights.70.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5377 - accuracy: 0.7381
# Epoch 71/100
# 781/804 [============================>.] - ETA: 0s - loss: 0.5371 - accuracy: 0.7389
# Epoch 71: saving model to checkpoints/weights.71.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5374 - accuracy: 0.7385
# Epoch 72/100
# 786/804 [============================>.] - ETA: 0s - loss: 0.5376 - accuracy: 0.7386
# Epoch 72: saving model to checkpoints/weights.72.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5375 - accuracy: 0.7383
# Epoch 73/100
# 793/804 [============================>.] - ETA: 0s - loss: 0.5364 - accuracy: 0.7403
# Epoch 73: saving model to checkpoints/weights.73.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5370 - accuracy: 0.7394
# Epoch 74/100
# 793/804 [============================>.] - ETA: 0s - loss: 0.5371 - accuracy: 0.7388
# Epoch 74: saving model to checkpoints/weights.74.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5372 - accuracy: 0.7390
# Epoch 75/100
# 784/804 [============================>.] - ETA: 0s - loss: 0.5368 - accuracy: 0.7390
# Epoch 75: saving model to checkpoints/weights.75.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5370 - accuracy: 0.7387
# Epoch 76/100
# 783/804 [============================>.] - ETA: 0s - loss: 0.5366 - accuracy: 0.7391
# Epoch 76: saving model to checkpoints/weights.76.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5369 - accuracy: 0.7390
# Epoch 77/100
# 783/804 [============================>.] - ETA: 0s - loss: 0.5372 - accuracy: 0.7387
# Epoch 77: saving model to checkpoints/weights.77.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5370 - accuracy: 0.7390
# Epoch 78/100
# 796/804 [============================>.] - ETA: 0s - loss: 0.5368 - accuracy: 0.7397
# Epoch 78: saving model to checkpoints/weights.78.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5372 - accuracy: 0.7393
# Epoch 79/100
# 788/804 [============================>.] - ETA: 0s - loss: 0.5366 - accuracy: 0.7394
# Epoch 79: saving model to checkpoints/weights.79.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5371 - accuracy: 0.7389
# Epoch 80/100
# 792/804 [============================>.] - ETA: 0s - loss: 0.5366 - accuracy: 0.7388
# Epoch 80: saving model to checkpoints/weights.80.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5365 - accuracy: 0.7388
# Epoch 81/100
# 802/804 [============================>.] - ETA: 0s - loss: 0.5366 - accuracy: 0.7385
# Epoch 81: saving model to checkpoints/weights.81.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5365 - accuracy: 0.7388
# Epoch 82/100
# 802/804 [============================>.] - ETA: 0s - loss: 0.5364 - accuracy: 0.7395
# Epoch 82: saving model to checkpoints/weights.82.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5362 - accuracy: 0.7396
# Epoch 83/100
# 795/804 [============================>.] - ETA: 0s - loss: 0.5370 - accuracy: 0.7374
# Epoch 83: saving model to checkpoints/weights.83.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5368 - accuracy: 0.7378
# Epoch 84/100
# 792/804 [============================>.] - ETA: 0s - loss: 0.5362 - accuracy: 0.7396
# Epoch 84: saving model to checkpoints/weights.84.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5366 - accuracy: 0.7391
# Epoch 85/100
# 785/804 [============================>.] - ETA: 0s - loss: 0.5362 - accuracy: 0.7390
# Epoch 85: saving model to checkpoints/weights.85.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5365 - accuracy: 0.7390
# Epoch 86/100
# 795/804 [============================>.] - ETA: 0s - loss: 0.5358 - accuracy: 0.7387
# Epoch 86: saving model to checkpoints/weights.86.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5364 - accuracy: 0.7380
# Epoch 87/100
# 789/804 [============================>.] - ETA: 0s - loss: 0.5362 - accuracy: 0.7388
# Epoch 87: saving model to checkpoints/weights.87.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5365 - accuracy: 0.7389
# Epoch 88/100
# 792/804 [============================>.] - ETA: 0s - loss: 0.5362 - accuracy: 0.7396
# Epoch 88: saving model to checkpoints/weights.88.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5363 - accuracy: 0.7395
# Epoch 89/100
# 804/804 [==============================] - ETA: 0s - loss: 0.5362 - accuracy: 0.7388
# Epoch 89: saving model to checkpoints/weights.89.hdf5
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5362 - accuracy: 0.7388
# Epoch 90/100
# 796/804 [============================>.] - ETA: 0s - loss: 0.5365 - accuracy: 0.7386
# Epoch 90: saving model to checkpoints/weights.90.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5365 - accuracy: 0.7389
# Epoch 91/100
# 790/804 [============================>.] - ETA: 0s - loss: 0.5362 - accuracy: 0.7391
# Epoch 91: saving model to checkpoints/weights.91.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5360 - accuracy: 0.7388
# Epoch 92/100
# 796/804 [============================>.] - ETA: 0s - loss: 0.5361 - accuracy: 0.7392
# Epoch 92: saving model to checkpoints/weights.92.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5359 - accuracy: 0.7393
# Epoch 93/100
# 798/804 [============================>.] - ETA: 0s - loss: 0.5360 - accuracy: 0.7390
# Epoch 93: saving model to checkpoints/weights.93.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5360 - accuracy: 0.7389
# Epoch 94/100
# 803/804 [============================>.] - ETA: 0s - loss: 0.5362 - accuracy: 0.7394
# Epoch 94: saving model to checkpoints/weights.94.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5361 - accuracy: 0.7394
# Epoch 95/100
# 789/804 [============================>.] - ETA: 0s - loss: 0.5366 - accuracy: 0.7391
# Epoch 95: saving model to checkpoints/weights.95.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5362 - accuracy: 0.7398
# Epoch 96/100
# 783/804 [============================>.] - ETA: 0s - loss: 0.5361 - accuracy: 0.7390
# Epoch 96: saving model to checkpoints/weights.96.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5360 - accuracy: 0.7392
# Epoch 97/100
# 791/804 [============================>.] - ETA: 0s - loss: 0.5352 - accuracy: 0.7391
# Epoch 97: saving model to checkpoints/weights.97.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5360 - accuracy: 0.7386
# Epoch 98/100
# 785/804 [============================>.] - ETA: 0s - loss: 0.5366 - accuracy: 0.7377
# Epoch 98: saving model to checkpoints/weights.98.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5363 - accuracy: 0.7383
# Epoch 99/100
# 791/804 [============================>.] - ETA: 0s - loss: 0.5358 - accuracy: 0.7388
# Epoch 99: saving model to checkpoints/weights.99.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5360 - accuracy: 0.7386
# Epoch 100/100
# 803/804 [============================>.] - ETA: 0s - loss: 0.5360 - accuracy: 0.7395
# Epoch 100: saving model to checkpoints/weights.100.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5360 - accuracy: 0.7395

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5567 - accuracy: 0.7305 - 430ms/epoch - 2ms/step
# Loss: 0.5566768050193787, Accuracy: 0.7304956316947937

# %% [markdown]
# Another thing

# %%
#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://raw.githubusercontent.com/slstapleton/Neural_Network_Charity_Analysis/main/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(labels=["EIN", "NAME"], axis=1)

# %%
# Look at APPLICATION_TYPE value counts for binning
application_counts = application_df.APPLICATION_TYPE.value_counts()

# Determine which values to replace if counts are less than ...?
replace_application = list(application_counts[application_counts < 200].index)

# Replace in dataframe
for app in replace_application:
    application_df.APPLICATION_TYPE = application_df.APPLICATION_TYPE.replace(app,"Other")

# %%
# Look at CLASSIFICATION value counts for binning
class_counts = application_df.CLASSIFICATION.value_counts()

# Determine which values to replace if counts are less than ..?
replace_class = list(class_counts[class_counts < 1500].index)

# Replace in dataframe
for cls in replace_class:
    application_df.CLASSIFICATION = application_df.CLASSIFICATION.replace(cls,"Other")

# %%
# Generate our categorical variable lists
application_cat = list(application_df.dtypes[application_df.dtypes == "object"].index)

# %%
# Create a OneHotEncoder instance
enc = OneHotEncoder(sparse=False)

# Fit and transform the OneHotEncoder using the categorical variable list
encode_df = pd.DataFrame(enc.fit_transform(application_df[application_cat]))

# Add the encoded variable names to the dataframe
encode_df.columns = enc.get_feature_names(application_cat)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Merge one-hot encoded features and drop the originals
application_df = application_df.merge(encode_df, left_index=True, right_index=True)
application_df = application_df.drop(labels=application_cat, axis=1)

# %%
# Split our preprocessed data into our features and target arrays
y = application_df["IS_SUCCESSFUL"].values.reshape(-1, 1)
X = application_df.drop("IS_SUCCESSFUL", axis=1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 30

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 80)                3520
#
#  dense_9 (Dense)             (None, 30)                2430
#
#  dense_10 (Dense)            (None, 1)                 31
#
# =================================================================
# Total params: 5,981
# Trainable params: 5,981
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Add model weight checkpoints during training
import os
from tensorflow.keras.callbacks import ModelCheckpoint
os.makedirs("checkpoints/", exist_ok=True)
checkpoint_path="checkpoints/weights.{epoch}.hdf5"

# Create a callback that saves the model's weights every epoch
cp_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    verbose=5,
    save_weights_only=True,
    save_freq='epoch')

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100,callbacks=[cp_callback])
# Out:
# Epoch 1/100
# 804/804 [==============================] - ETA: 0s - loss: 0.5707 - accuracy: 0.7187
# Epoch 1: saving model to checkpoints/weights.1.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5707 - accuracy: 0.7187
# Epoch 2/100
# 792/804 [============================>.] - ETA: 0s - loss: 0.5569 - accuracy: 0.7269
# Epoch 2: saving model to checkpoints/weights.2.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5566 - accuracy: 0.7272
# Epoch 3/100
# 792/804 [============================>.] - ETA: 0s - loss: 0.5539 - accuracy: 0.7277
# Epoch 3: saving model to checkpoints/weights.3.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5538 - accuracy: 0.7280
# Epoch 4/100
# 781/804 [============================>.] - ETA: 0s - loss: 0.5520 - accuracy: 0.7285
# Epoch 4: saving model to checkpoints/weights.4.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5517 - accuracy: 0.7283
# Epoch 5/100
# 800/804 [============================>.] - ETA: 0s - loss: 0.5501 - accuracy: 0.7298
# Epoch 5: saving model to checkpoints/weights.5.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5496 - accuracy: 0.7302
# Epoch 6/100
# 794/804 [============================>.] - ETA: 0s - loss: 0.5496 - accuracy: 0.7298
# Epoch 6: saving model to checkpoints/weights.6.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5495 - accuracy: 0.7303
# Epoch 7/100
# 794/804 [============================>.] - ETA: 0s - loss: 0.5482 - accuracy: 0.7320
# Epoch 7: saving model to checkpoints/weights.7.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5487 - accuracy: 0.7316
# Epoch 8/100
# 803/804 [============================>.] - ETA: 0s - loss: 0.5481 - accuracy: 0.7304
# Epoch 8: saving model to checkpoints/weights.8.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5481 - accuracy: 0.7303
# Epoch 9/100
# 803/804 [============================>.] - ETA: 0s - loss: 0.5472 - accuracy: 0.7323
# Epoch 9: saving model to checkpoints/weights.9.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5471 - accuracy: 0.7324
# Epoch 10/100
# 796/804 [============================>.] - ETA: 0s - loss: 0.5471 - accuracy: 0.7316
# Epoch 10: saving model to checkpoints/weights.10.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5472 - accuracy: 0.7318
# Epoch 11/100
# 778/804 [============================>.] - ETA: 0s - loss: 0.5472 - accuracy: 0.7324
# Epoch 11: saving model to checkpoints/weights.11.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5463 - accuracy: 0.7332
# Epoch 12/100
# 803/804 [============================>.] - ETA: 0s - loss: 0.5462 - accuracy: 0.7321
# Epoch 12: saving model to checkpoints/weights.12.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5463 - accuracy: 0.7320
# Epoch 13/100
# 796/804 [============================>.] - ETA: 0s - loss: 0.5446 - accuracy: 0.7336
# Epoch 13: saving model to checkpoints/weights.13.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5452 - accuracy: 0.7331
# Epoch 14/100
# 775/804 [===========================>..] - ETA: 0s - loss: 0.5443 - accuracy: 0.7333
# Epoch 14: saving model to checkpoints/weights.14.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5452 - accuracy: 0.7331
# Epoch 15/100
# 789/804 [============================>.] - ETA: 0s - loss: 0.5446 - accuracy: 0.7341
# Epoch 15: saving model to checkpoints/weights.15.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5445 - accuracy: 0.7345
# Epoch 16/100
# 786/804 [============================>.] - ETA: 0s - loss: 0.5447 - accuracy: 0.7325
# Epoch 16: saving model to checkpoints/weights.16.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5448 - accuracy: 0.7325
# Epoch 17/100
# 793/804 [============================>.] - ETA: 0s - loss: 0.5439 - accuracy: 0.7341
# Epoch 17: saving model to checkpoints/weights.17.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5445 - accuracy: 0.7337
# Epoch 18/100
# 786/804 [============================>.] - ETA: 0s - loss: 0.5443 - accuracy: 0.7347
# Epoch 18: saving model to checkpoints/weights.18.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5440 - accuracy: 0.7348
# Epoch 19/100
# 804/804 [==============================] - ETA: 0s - loss: 0.5443 - accuracy: 0.7346
# Epoch 19: saving model to checkpoints/weights.19.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5443 - accuracy: 0.7346
# Epoch 20/100
# 795/804 [============================>.] - ETA: 0s - loss: 0.5435 - accuracy: 0.7339
# Epoch 20: saving model to checkpoints/weights.20.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5435 - accuracy: 0.7339
# Epoch 21/100
# 799/804 [============================>.] - ETA: 0s - loss: 0.5429 - accuracy: 0.7358
# Epoch 21: saving model to checkpoints/weights.21.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5432 - accuracy: 0.7357
# Epoch 22/100
# 793/804 [============================>.] - ETA: 0s - loss: 0.5433 - accuracy: 0.7340
# Epoch 22: saving model to checkpoints/weights.22.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5431 - accuracy: 0.7343
# Epoch 23/100
# 791/804 [============================>.] - ETA: 0s - loss: 0.5431 - accuracy: 0.7346
# Epoch 23: saving model to checkpoints/weights.23.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5430 - accuracy: 0.7343
# Epoch 24/100
# 802/804 [============================>.] - ETA: 0s - loss: 0.5429 - accuracy: 0.7351
# Epoch 24: saving model to checkpoints/weights.24.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5429 - accuracy: 0.7351
# Epoch 25/100
# 790/804 [============================>.] - ETA: 0s - loss: 0.5436 - accuracy: 0.7344
# Epoch 25: saving model to checkpoints/weights.25.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5432 - accuracy: 0.7348
# Epoch 26/100
# 787/804 [============================>.] - ETA: 0s - loss: 0.5424 - accuracy: 0.7345
# Epoch 26: saving model to checkpoints/weights.26.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5425 - accuracy: 0.7346
# Epoch 27/100
# 787/804 [============================>.] - ETA: 0s - loss: 0.5420 - accuracy: 0.7355
# Epoch 27: saving model to checkpoints/weights.27.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5422 - accuracy: 0.7354
# Epoch 28/100
# 803/804 [============================>.] - ETA: 0s - loss: 0.5422 - accuracy: 0.7347
# Epoch 28: saving model to checkpoints/weights.28.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5421 - accuracy: 0.7347
# Epoch 29/100
# 795/804 [============================>.] - ETA: 0s - loss: 0.5421 - accuracy: 0.7353
# Epoch 29: saving model to checkpoints/weights.29.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5420 - accuracy: 0.7352
# Epoch 30/100
# 799/804 [============================>.] - ETA: 0s - loss: 0.5418 - accuracy: 0.7344
# Epoch 30: saving model to checkpoints/weights.30.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5422 - accuracy: 0.7341
# Epoch 31/100
# 794/804 [============================>.] - ETA: 0s - loss: 0.5411 - accuracy: 0.7349
# Epoch 31: saving model to checkpoints/weights.31.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5415 - accuracy: 0.7347
# Epoch 32/100
# 802/804 [============================>.] - ETA: 0s - loss: 0.5412 - accuracy: 0.7362
# Epoch 32: saving model to checkpoints/weights.32.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5412 - accuracy: 0.7363
# Epoch 33/100
# 785/804 [============================>.] - ETA: 0s - loss: 0.5415 - accuracy: 0.7357
# Epoch 33: saving model to checkpoints/weights.33.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5416 - accuracy: 0.7357
# Epoch 34/100
# 785/804 [============================>.] - ETA: 0s - loss: 0.5417 - accuracy: 0.7357
# Epoch 34: saving model to checkpoints/weights.34.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5412 - accuracy: 0.7359
# Epoch 35/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.5414 - accuracy: 0.7354
# Epoch 35: saving model to checkpoints/weights.35.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5415 - accuracy: 0.7353
# Epoch 36/100
# 790/804 [============================>.] - ETA: 0s - loss: 0.5409 - accuracy: 0.7354
# Epoch 36: saving model to checkpoints/weights.36.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5408 - accuracy: 0.7355
# Epoch 37/100
# 794/804 [============================>.] - ETA: 0s - loss: 0.5407 - accuracy: 0.7347
# Epoch 37: saving model to checkpoints/weights.37.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5405 - accuracy: 0.7346
# Epoch 38/100
# 796/804 [============================>.] - ETA: 0s - loss: 0.5408 - accuracy: 0.7358
# Epoch 38: saving model to checkpoints/weights.38.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5410 - accuracy: 0.7356
# Epoch 39/100
# 789/804 [============================>.] - ETA: 0s - loss: 0.5401 - accuracy: 0.7359
# Epoch 39: saving model to checkpoints/weights.39.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5404 - accuracy: 0.7358
# Epoch 40/100
# 784/804 [============================>.] - ETA: 0s - loss: 0.5400 - accuracy: 0.7360
# Epoch 40: saving model to checkpoints/weights.40.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5402 - accuracy: 0.7358
# Epoch 41/100
# 796/804 [============================>.] - ETA: 0s - loss: 0.5403 - accuracy: 0.7358
# Epoch 41: saving model to checkpoints/weights.41.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5402 - accuracy: 0.7359
# Epoch 42/100
# 779/804 [============================>.] - ETA: 0s - loss: 0.5402 - accuracy: 0.7368
# Epoch 42: saving model to checkpoints/weights.42.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5405 - accuracy: 0.7365
# Epoch 43/100
# 777/804 [===========================>..] - ETA: 0s - loss: 0.5404 - accuracy: 0.7360
# Epoch 43: saving model to checkpoints/weights.43.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5404 - accuracy: 0.7361
# Epoch 44/100
# 787/804 [============================>.] - ETA: 0s - loss: 0.5406 - accuracy: 0.7360
# Epoch 44: saving model to checkpoints/weights.44.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5400 - accuracy: 0.7367
# Epoch 45/100
# 797/804 [============================>.] - ETA: 0s - loss: 0.5399 - accuracy: 0.7356
# Epoch 45: saving model to checkpoints/weights.45.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5402 - accuracy: 0.7355
# Epoch 46/100
# 791/804 [============================>.] - ETA: 0s - loss: 0.5405 - accuracy: 0.7353
# Epoch 46: saving model to checkpoints/weights.46.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5396 - accuracy: 0.7360
# Epoch 47/100
# 790/804 [============================>.] - ETA: 0s - loss: 0.5394 - accuracy: 0.7360
# Epoch 47: saving model to checkpoints/weights.47.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5400 - accuracy: 0.7354
# Epoch 48/100
# 797/804 [============================>.] - ETA: 0s - loss: 0.5391 - accuracy: 0.7358
# Epoch 48: saving model to checkpoints/weights.48.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5394 - accuracy: 0.7356
# Epoch 49/100
# 794/804 [============================>.] - ETA: 0s - loss: 0.5399 - accuracy: 0.7369
# Epoch 49: saving model to checkpoints/weights.49.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5395 - accuracy: 0.7370
# Epoch 50/100
# 788/804 [============================>.] - ETA: 0s - loss: 0.5397 - accuracy: 0.7361
# Epoch 50: saving model to checkpoints/weights.50.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5393 - accuracy: 0.7367
# Epoch 51/100
# 779/804 [============================>.] - ETA: 0s - loss: 0.5388 - accuracy: 0.7374
# Epoch 51: saving model to checkpoints/weights.51.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5390 - accuracy: 0.7373
# Epoch 52/100
# 786/804 [============================>.] - ETA: 0s - loss: 0.5385 - accuracy: 0.7364
# Epoch 52: saving model to checkpoints/weights.52.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5389 - accuracy: 0.7362
# Epoch 53/100
# 779/804 [============================>.] - ETA: 0s - loss: 0.5384 - accuracy: 0.7359
# Epoch 53: saving model to checkpoints/weights.53.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5389 - accuracy: 0.7358
# Epoch 54/100
# 797/804 [============================>.] - ETA: 0s - loss: 0.5392 - accuracy: 0.7364
# Epoch 54: saving model to checkpoints/weights.54.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5390 - accuracy: 0.7365
# Epoch 55/100
# 794/804 [============================>.] - ETA: 0s - loss: 0.5383 - accuracy: 0.7366
# Epoch 55: saving model to checkpoints/weights.55.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5387 - accuracy: 0.7364
# Epoch 56/100
# 777/804 [===========================>..] - ETA: 0s - loss: 0.5388 - accuracy: 0.7368
# Epoch 56: saving model to checkpoints/weights.56.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5386 - accuracy: 0.7368
# Epoch 57/100
# 792/804 [============================>.] - ETA: 0s - loss: 0.5381 - accuracy: 0.7378
# Epoch 57: saving model to checkpoints/weights.57.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5382 - accuracy: 0.7374
# Epoch 58/100
# 778/804 [============================>.] - ETA: 0s - loss: 0.5379 - accuracy: 0.7365
# Epoch 58: saving model to checkpoints/weights.58.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5382 - accuracy: 0.7364
# Epoch 59/100
# 778/804 [============================>.] - ETA: 0s - loss: 0.5386 - accuracy: 0.7362
# Epoch 59: saving model to checkpoints/weights.59.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5386 - accuracy: 0.7365
# Epoch 60/100
# 783/804 [============================>.] - ETA: 0s - loss: 0.5379 - accuracy: 0.7379
# Epoch 60: saving model to checkpoints/weights.60.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5381 - accuracy: 0.7375
# Epoch 61/100
# 790/804 [============================>.] - ETA: 0s - loss: 0.5382 - accuracy: 0.7364
# Epoch 61: saving model to checkpoints/weights.61.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5381 - accuracy: 0.7362
# Epoch 62/100
# 794/804 [============================>.] - ETA: 0s - loss: 0.5386 - accuracy: 0.7374
# Epoch 62: saving model to checkpoints/weights.62.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5384 - accuracy: 0.7374
# Epoch 63/100
# 803/804 [============================>.] - ETA: 0s - loss: 0.5382 - accuracy: 0.7365
# Epoch 63: saving model to checkpoints/weights.63.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5383 - accuracy: 0.7363
# Epoch 64/100
# 787/804 [============================>.] - ETA: 0s - loss: 0.5383 - accuracy: 0.7363
# Epoch 64: saving model to checkpoints/weights.64.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5383 - accuracy: 0.7359
# Epoch 65/100
# 781/804 [============================>.] - ETA: 0s - loss: 0.5383 - accuracy: 0.7366
# Epoch 65: saving model to checkpoints/weights.65.hdf5
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5378 - accuracy: 0.7371
# Epoch 66/100
# 803/804 [============================>.] - ETA: 0s - loss: 0.5374 - accuracy: 0.7373
# Epoch 66: saving model to checkpoints/weights.66.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5375 - accuracy: 0.7371
# Epoch 67/100
# 776/804 [===========================>..] - ETA: 0s - loss: 0.5382 - accuracy: 0.7368
# Epoch 67: saving model to checkpoints/weights.67.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5381 - accuracy: 0.7371
# Epoch 68/100
# 799/804 [============================>.] - ETA: 0s - loss: 0.5384 - accuracy: 0.7369
# Epoch 68: saving model to checkpoints/weights.68.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5382 - accuracy: 0.7369
# Epoch 69/100
# 798/804 [============================>.] - ETA: 0s - loss: 0.5381 - accuracy: 0.7360
# Epoch 69: saving model to checkpoints/weights.69.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5377 - accuracy: 0.7364
# Epoch 70/100
# 798/804 [============================>.] - ETA: 0s - loss: 0.5378 - accuracy: 0.7376
# Epoch 70: saving model to checkpoints/weights.70.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5378 - accuracy: 0.7376
# Epoch 71/100
# 784/804 [============================>.] - ETA: 0s - loss: 0.5385 - accuracy: 0.7364
# Epoch 71: saving model to checkpoints/weights.71.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5378 - accuracy: 0.7374
# Epoch 72/100
# 804/804 [==============================] - ETA: 0s - loss: 0.5373 - accuracy: 0.7371
# Epoch 72: saving model to checkpoints/weights.72.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5373 - accuracy: 0.7371
# Epoch 73/100
# 796/804 [============================>.] - ETA: 0s - loss: 0.5369 - accuracy: 0.7380
# Epoch 73: saving model to checkpoints/weights.73.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5373 - accuracy: 0.7376
# Epoch 74/100
# 798/804 [============================>.] - ETA: 0s - loss: 0.5372 - accuracy: 0.7375
# Epoch 74: saving model to checkpoints/weights.74.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5371 - accuracy: 0.7376
# Epoch 75/100
# 791/804 [============================>.] - ETA: 0s - loss: 0.5374 - accuracy: 0.7372
# Epoch 75: saving model to checkpoints/weights.75.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5372 - accuracy: 0.7373
# Epoch 76/100
# 803/804 [============================>.] - ETA: 0s - loss: 0.5375 - accuracy: 0.7372
# Epoch 76: saving model to checkpoints/weights.76.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5376 - accuracy: 0.7372
# Epoch 77/100
# 790/804 [============================>.] - ETA: 0s - loss: 0.5373 - accuracy: 0.7377
# Epoch 77: saving model to checkpoints/weights.77.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5375 - accuracy: 0.7377
# Epoch 78/100
# 799/804 [============================>.] - ETA: 0s - loss: 0.5372 - accuracy: 0.7376
# Epoch 78: saving model to checkpoints/weights.78.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5371 - accuracy: 0.7378
# Epoch 79/100
# 797/804 [============================>.] - ETA: 0s - loss: 0.5375 - accuracy: 0.7372
# Epoch 79: saving model to checkpoints/weights.79.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5375 - accuracy: 0.7370
# Epoch 80/100
# 776/804 [===========================>..] - ETA: 0s - loss: 0.5363 - accuracy: 0.7380
# Epoch 80: saving model to checkpoints/weights.80.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5370 - accuracy: 0.7374
# Epoch 81/100
# 799/804 [============================>.] - ETA: 0s - loss: 0.5372 - accuracy: 0.7378
# Epoch 81: saving model to checkpoints/weights.81.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5371 - accuracy: 0.7380
# Epoch 82/100
# 786/804 [============================>.] - ETA: 0s - loss: 0.5372 - accuracy: 0.7374
# Epoch 82: saving model to checkpoints/weights.82.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5366 - accuracy: 0.7380
# Epoch 83/100
# 783/804 [============================>.] - ETA: 0s - loss: 0.5361 - accuracy: 0.7379
# Epoch 83: saving model to checkpoints/weights.83.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5368 - accuracy: 0.7381
# Epoch 84/100
# 784/804 [============================>.] - ETA: 0s - loss: 0.5368 - accuracy: 0.7380
# Epoch 84: saving model to checkpoints/weights.84.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5371 - accuracy: 0.7378
# Epoch 85/100
# 785/804 [============================>.] - ETA: 0s - loss: 0.5365 - accuracy: 0.7373
# Epoch 85: saving model to checkpoints/weights.85.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5366 - accuracy: 0.7376
# Epoch 86/100
# 803/804 [============================>.] - ETA: 0s - loss: 0.5365 - accuracy: 0.7388
# Epoch 86: saving model to checkpoints/weights.86.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5365 - accuracy: 0.7389
# Epoch 87/100
# 782/804 [============================>.] - ETA: 0s - loss: 0.5374 - accuracy: 0.7380
# Epoch 87: saving model to checkpoints/weights.87.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5369 - accuracy: 0.7383
# Epoch 88/100
# 799/804 [============================>.] - ETA: 0s - loss: 0.5364 - accuracy: 0.7384
# Epoch 88: saving model to checkpoints/weights.88.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5371 - accuracy: 0.7379
# Epoch 89/100
# 797/804 [============================>.] - ETA: 0s - loss: 0.5364 - accuracy: 0.7375
# Epoch 89: saving model to checkpoints/weights.89.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5364 - accuracy: 0.7376
# Epoch 90/100
# 788/804 [============================>.] - ETA: 0s - loss: 0.5361 - accuracy: 0.7386
# Epoch 90: saving model to checkpoints/weights.90.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5365 - accuracy: 0.7381
# Epoch 91/100
# 787/804 [============================>.] - ETA: 0s - loss: 0.5371 - accuracy: 0.7371
# Epoch 91: saving model to checkpoints/weights.91.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5365 - accuracy: 0.7378
# Epoch 92/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.5369 - accuracy: 0.7371
# Epoch 92: saving model to checkpoints/weights.92.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5368 - accuracy: 0.7373
# Epoch 93/100
# 798/804 [============================>.] - ETA: 0s - loss: 0.5369 - accuracy: 0.7375
# Epoch 93: saving model to checkpoints/weights.93.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5366 - accuracy: 0.7378
# Epoch 94/100
# 777/804 [===========================>..] - ETA: 0s - loss: 0.5361 - accuracy: 0.7379
# Epoch 94: saving model to checkpoints/weights.94.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5363 - accuracy: 0.7382
# Epoch 95/100
# 779/804 [============================>.] - ETA: 0s - loss: 0.5357 - accuracy: 0.7389
# Epoch 95: saving model to checkpoints/weights.95.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5366 - accuracy: 0.7382
# Epoch 96/100
# 790/804 [============================>.] - ETA: 0s - loss: 0.5358 - accuracy: 0.7384
# Epoch 96: saving model to checkpoints/weights.96.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5362 - accuracy: 0.7384
# Epoch 97/100
# 784/804 [============================>.] - ETA: 0s - loss: 0.5366 - accuracy: 0.7381
# Epoch 97: saving model to checkpoints/weights.97.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5362 - accuracy: 0.7383
# Epoch 98/100
# 801/804 [============================>.] - ETA: 0s - loss: 0.5363 - accuracy: 0.7387
# Epoch 98: saving model to checkpoints/weights.98.hdf5
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5361 - accuracy: 0.7389
# Epoch 99/100
# 786/804 [============================>.] - ETA: 0s - loss: 0.5360 - accuracy: 0.7379
# Epoch 99: saving model to checkpoints/weights.99.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5358 - accuracy: 0.7381
# Epoch 100/100
# 781/804 [============================>.] - ETA: 0s - loss: 0.5368 - accuracy: 0.7387
# Epoch 100: saving model to checkpoints/weights.100.hdf5
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5363 - accuracy: 0.7389

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5550 - accuracy: 0.7327 - 790ms/epoch - 3ms/step
# Loss: 0.5549589395523071, Accuracy: 0.7327113747596741
